# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load Dataset

# %%
train_df = pd.read_csv('fashion-mnist_train.csv')
test_df = pd.read_csv('fashion-mnist_test.csv')

# %%
train_df.shape
# Out:
# (60000, 785)

# %%
test_df.shape
# Out:
# (10000, 785)

# %%
train_df.describe()
# Out:
#               label        pixel1        pixel2        pixel3        pixel4  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       4.500000      0.000900      0.006150      0.035333      0.101933
# std        2.872305      0.094689      0.271011      1.222324      2.452871
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000      0.000000      0.000000      0.000000      0.000000
# 50%        4.500000      0.000000      0.000000      0.000000      0.000000
# 75%        7.000000      0.000000      0.000000      0.000000      0.000000
# max        9.000000     16.000000     36.000000    226.000000    164.000000
#
#              pixel5        pixel6        pixel7        pixel8        pixel9  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       0.247967      0.411467      0.805767      2.198283      5.682000
# std        4.306912      5.836188      8.215169     14.093378     23.819481
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      227.000000    230.000000    224.000000    255.000000    254.000000
#
#        ...      pixel775      pixel776      pixel777      pixel778  \
# count  ...  60000.000000  60000.000000  60000.000000  60000.000000
# mean   ...     34.625400     23.300683     16.588267     17.869433
# std    ...     57.545242     48.854427     41.979611     43.966032
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...     58.000000      9.000000      0.000000      0.000000
# max    ...    255.000000    255.000000    255.000000    255.000000
#
#            pixel779      pixel780      pixel781      pixel782      pixel783  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean      22.814817     17.911483      8.520633      2.753300      0.855517
# std       51.830477     45.149388     29.614859     17.397652      9.356960
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      255.000000    255.000000    255.000000    255.000000    255.000000
#
#           pixel784
# count  60000.00000
# mean       0.07025
# std        2.12587
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max      170.00000
#
# [8 rows x 785 columns]

# %%
train_df.label.unique()
# Out:
# array([2, 9, 6, 0, 3, 4, 5, 8, 7, 1], dtype=int64)

# %% [markdown]
# #### Each row represents an grayscale image containing 784 pixels and each pixel having values in range from 0-255
# #### The column label is a discrete value in the range 0 to 9 each value representing a specific category

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ### Preprocess Data
# Convert each image of 784 into (28x28x1)(height x width x color_channels). Divide values by 255 to scale the values.

# %%
x_train = train_df.iloc[:,1:].to_numpy()
x_train = x_train.reshape([-1,28,28,1])
x_train = x_train / 255

# %%
y_train = train_df.iloc[:,0].to_numpy()

# %%
x_test = test_df.iloc[:,1:].to_numpy()
x_test = x_test.reshape([-1,28,28,1])
x_test = x_test / 255

# %%
y_test = test_df.iloc[:,0].to_numpy()

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ### Model Building

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,Dropout

# %%
model = Sequential()

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape=(28,28,1),activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(rate=0.3))
model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=10, activation='sigmoid'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# C:\Users\DIYA\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 10816)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │       346,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 347,114 (1.32 MB)
#  Trainable params: 347,114 (1.32 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train,epochs=50,batch_size=1200,validation_split=0.05)
# Out:
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 33s 585ms/step - accuracy: 0.5675 - loss: 1.3109 - val_accuracy: 0.8020 - val_loss: 0.5441
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 25s 526ms/step - accuracy: 0.8185 - loss: 0.5065 - val_accuracy: 0.8500 - val_loss: 0.4385
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 25s 509ms/step - accuracy: 0.8533 - loss: 0.4216 - val_accuracy: 0.8670 - val_loss: 0.3860
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 25s 521ms/step - accuracy: 0.8694 - loss: 0.3710 - val_accuracy: 0.8763 - val_loss: 0.3553
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 26s 544ms/step - accuracy: 0.8780 - loss: 0.3497 - val_accuracy: 0.8827 - val_loss: 0.3402
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 29s 599ms/step - accuracy: 0.8840 - loss: 0.3265 - val_accuracy: 0.8907 - val_loss: 0.3202
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 29s 597ms/step - accuracy: 0.8901 - loss: 0.3156 - val_accuracy: 0.8903 - val_loss: 0.3154
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 26s 536ms/step - accuracy: 0.8929 - loss: 0.3021 - val_accuracy: 0.8893 - val_loss: 0.3061
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━
50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 27s 563ms/step - accuracy: 0.9301 - loss: 0.1940 - val_accuracy: 0.9153 - val_loss: 0.2442
# Epoch 35/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 28s 578ms/step - accuracy: 0.9331 - loss: 0.1877 - val_accuracy: 0.9173 - val_loss: 0.2427
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 27s 555ms/step - accuracy: 0.9334 - loss: 0.1823 - val_accuracy: 0.9173 - val_loss: 0.2438
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 28s 576ms/step - accuracy: 0.9343 - loss: 0.1844 - val_accuracy: 0.9177 - val_loss: 0.2423
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 33s 696ms/step - accuracy: 0.9355 - loss: 0.1799 - val_accuracy: 0.9153 - val_loss: 0.2426
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 36s 577ms/step - accuracy: 0.9346 - loss: 0.1832 - val_accuracy: 0.9180 - val_loss: 0.2380
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 28s 576ms/step - accuracy: 0.9362 - loss: 0.1771 - val_accuracy: 0.9157 - val_loss: 0.2407
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 30s 613ms/step - accuracy: 0.9357 - loss: 0.1802 - val_accuracy: 0.9197 - val_loss: 0.2393
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 28s 573ms/step - accuracy: 0.9403 - loss: 0.1683 - val_accuracy: 0.9167 - val_loss: 0.2451
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 25s 520ms/step - accuracy: 0.9380 - loss: 0.1738 - val_accuracy: 0.9140 - val_loss: 0.2448
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 27s 568ms/step - accuracy: 0.9410 - loss: 0.1677 - val_accuracy: 0.9123 - val_loss: 0.2416
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 31s 653ms/step - accuracy: 0.9371 - loss: 0.1794 - val_accuracy: 0.8850 - val_loss: 0.3251
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 29s 613ms/step - accuracy: 0.8972 - loss: 0.2945 - val_accuracy: 0.8907 - val_loss: 0.2960
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 39s 557ms/step - accuracy: 0.9053 - loss: 0.2682 - val_accuracy: 0.8957 - val_loss: 0.2879
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 27s 553ms/step - accuracy: 0.9063 - loss: 0.2602 - val_accuracy: 0.8930 - val_loss: 0.2823
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 26s 540ms/step - accuracy: 0.9091 - loss: 0.2506 - val_accuracy: 0.8987 - val_loss: 0.2779
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 26s 539ms/step - accuracy: 0.9143 - loss: 0.2399 - val_accuracy: 0.8987 - val_loss: 0.2740

# %% [markdown]
# ### Evaluation

# %%
evaluation = model.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8978 - loss: 0.2783

# %%
print(f"Accuracy: {evaluation[1]}")
# Out:
# Accuracy: 0.902400016784668

# %%
y_probas = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %%
y_pred = y_probas.argmax(axis=-1)

# %%
y_pred
# Out:
# array([0, 1, 2, ..., 8, 8, 1], dtype=int64)

# %%
plt.figure(figsize=(10,10),)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.binary)
#     plt.xlabel(f"True Class:{y_test[i]}")
    plt.title(f"Pred:{class_names[y_pred[i]]}")
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
num_classes = 10
class_names = ["class {}".format(i) for i in range(num_classes)]
cr = classification_report(y_test, y_pred, target_names=class_names)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.86      0.83      0.84      1000
#      class 1       0.99      0.98      0.98      1000
#      class 2       0.83      0.84      0.84      1000
#      class 3       0.90      0.93      0.92      1000
#      class 4       0.85      0.83      0.84      1000
#      class 5       0.99      0.97      0.98      1000
#      class 6       0.72      0.75      0.73      1000
#      class 7       0.95      0.96      0.95      1000
#      class 8       0.98      0.98      0.98      1000
#      class 9       0.95      0.96      0.96      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
